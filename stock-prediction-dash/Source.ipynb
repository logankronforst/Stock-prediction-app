# %%
pip install -r requirements.txt

# %%
! pip install --upgrade pip
1

# %%
! pip install dash==2.0.0

# %%
! pip install gevent

# %%
! python3 app.py
# Out:
# ::1 - - [2025-04-08 16:02:59] "GET / HTTP/1.1" 200 1988 0.207715
# ::1 - - [2025-04-08 16:02:59] "GET / HTTP/1.1" 200 1988 0.000497
# ::1 - - [2025-04-08 16:02:59] "GET /assets/styles.css?m=1744133337.9919899 HTTP/1.1" 304 141 0.003653
# ::1 - - [2025-04-08 16:02:59] "GET /_dash-layout HTTP/1.1" 200 2647 0.000939
# ::1 - - [2025-04-08 16:02:59] "GET /_dash-dependencies HTTP/1.1" 200 1253 0.000203
# ::1 - - [2025-04-08 16:02:59] "GET /_dash-component-suites/dash/dcc/async-datepicker.js HTTP/1.1" 304 66 0.000808
# ::1 - - [2025-04-08 16:02:59] "POST /_dash-update-component HTTP/1.1" 200 387 0.000475
# ::1 - - [2025-04-08 16:02:59] "POST /_dash-update-component HTTP/1.1" 200 168 0.000341
# ::1 - - [2025-04-08 16:02:59] "POST /_dash-update-component HTTP/1.1" 200 166 0.000209
# ::1 - - [2025-04-08 16:02:59] "POST /_dash-update-component HTTP/1.1" 200 170 0.000187
# ::1 - - [2025-04-08 16:02:59] "GET /assets/stocks-img.jpg HTTP/1.1" 304 145 0.000372
# ...
