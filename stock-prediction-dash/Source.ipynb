# %%
pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 36.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for peewee: filename=peewee-3.17.9-cp312-cp312-linux_x86_64.whl size=1029257 sha256=6a89c898cea1fdf27c788326e1dacd53ccdeb5c7035e7373d7baa5bcf8294952
#   Stored in directory: /home/codespace/.cache/pip/wheels/43/ef/2d/2c51d496bf084945ffdf838b4cc8767b8ba1cc20eb41588831
# Successfully built peewee
# ...
#   Attempting uninstall: yfinance
#     Found existing installation: yfinance 0.2.28
#     Uninstalling yfinance-0.2.28:
#       Successfully uninstalled yfinance-0.2.28
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
! pip install gevent

# %%
! python3 app.py
# Out:
# ::1 - - [2025-04-09 17:38:16] "GET / HTTP/1.1" 200 1988 0.278949
# ::1 - - [2025-04-09 17:38:16] "GET /assets/styles.css?m=1744171046.4764292 HTTP/1.1" 304 141 0.000857
# ::1 - - [2025-04-09 17:38:16] "GET /_dash-dependencies HTTP/1.1" 200 1253 0.000834
# ::1 - - [2025-04-09 17:38:16] "GET /_dash-layout HTTP/1.1" 200 2647 0.000893
# ::1 - - [2025-04-09 17:38:16] "POST /_dash-update-component HTTP/1.1" 200 387 0.000819
# ::1 - - [2025-04-09 17:38:16] "POST /_dash-update-component HTTP/1.1" 200 170 0.001076
# ::1 - - [2025-04-09 17:38:16] "POST /_dash-update-component HTTP/1.1" 200 166 0.001101
# ::1 - - [2025-04-09 17:38:17] "GET /_dash-component-suites/dash/dcc/async-datepicker.js HTTP/1.1" 304 66 0.000804
# ::1 - - [2025-04-09 17:38:17] "GET /assets/stocks-img.jpg HTTP/1.1" 304 145 0.000668
# ::1 - - [2025-04-09 17:38:17] "POST /_dash-update-component HTTP/1.1" 200 168 0.000411
# ::1 - - [2025-04-09 17:38:28] "POST /_dash-update-component HTTP/1.1" 200 166 0.000558
# ...
